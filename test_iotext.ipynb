# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import io

from matplotlib import pyplot as plt
from astropy    import units  as u

from common import hallmark as hm
from common import io_text as io
from common import viz
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
imgs = io.load_mov(['model/HAMR/sample_file.txt'])
meta = imgs.meta

# %%
ax = viz.show(imgs, s=0)

# %%
display(meta.mass, meta.dist, meta.freq)
display(meta.time, meta.width, meta.height)
# Out:
# <Quantity 4140000. solMass>
# <Quantity 8127. pc>
# <Quantity 230. GHz>
# <Quantity [0.] M>
# <Quantity 64. M>
# <Quantity 64. M>

# %%
display(meta.width.to(u.uas, meta.geom),
        meta.height.to(u.uas, meta.geom))
# Out:
# <Quantity 321.80654411 uas>
# <Quantity 321.80654411 uas>
